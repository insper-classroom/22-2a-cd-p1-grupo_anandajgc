# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Ananda\CDADOS 22.2\22-2a-cd-p1-grupo_anandajgc

# %%
filename = 'data/dados.xlsx'

# %%
train = pd.read_excel(filename, sheet_name = 'Treinamento')
train.head(5)
# Out:
#                Categoria                                             Titulo  \
# 0              Mercados   Ibovespa: ALPA4 fecha mais um pregão em alta e...
# 1              Empresas   IRB (IRBR3) é, de longe, a ação mais ‘shortead...
# 2  Carteira Recomendada   5 ações que pagam bons dividendos para investi...
# 3  Carteira Recomendada   Empiricus Investimentos escala 6 ações com div...
# 4              Mercados   Ibovespa futuro opera em queda com aversão ao ...
#
#                                        PrimeiroParag                Data  \
# 0  O Ibovespa (IBOV) fechou em queda de 1,09% nes...  26/08/2022 - 17:37
# 1  O IRB (IRBR3) é a ação com mais investidores s...  31/08/2022 - 17:00
# 2  Para setembro, a Órama Investimentos optou por...  05/09/2022 - 10:27
# 3  A Empiricus Investimentos, ex-Vitreo, incluiu ...  05/09/2022 - 13:21
# 4  O dólar abria o pregão desta segunda-feira (29...   29/08/2022 - 9:08
#
#    Pagina  Target
# 0      43       2
# 1      28       1
# 2      14       1
# 3      12       1
# 4      40       0

# %%
test = pd.read_excel(filename, sheet_name = 'Teste')
test.head(5)
# Out:
#                Categoria                                             Titulo  \
# 0              Mercados   Ibovespa (IBOV) vira para queda, com VALE3 ent...
# 1              Empresas   Ação da Braskem (BRKM3) avança com notícia sob...
# 2              Mercados   Compre commodities, se preocupe com recessão d...
# 3  Carteira Recomendada   Veja as 5 novas ações escaladas pela XP para e...
# 4            Mais Lidas   Respostas sobre Magazine Luiza (MGLU3) e mais ...
#
#                                        PrimeiroParag                Data  \
# 0  O Ibovespa (IBOV) operava sem forças nesta qua...  24/08/2022 - 13:58
# 1  As ações da Braskem (BRKM3) avançavam ao redor...  02/09/2022 - 11:30
# 2  O Goldman Sachs recomenda que os investidores ...   29/08/2022 - 9:49
# 3  A XP Investimentos repaginou sua carteira reco...   20/08/2022 - 9:31
# 4  Investidores não tiraram Magazine Luiza (MGLU3...  28/08/2022 - 10:30
#
#    Pagina  Target
# 0    53.0       2
# 1    20.0       2
# 2    40.0       1
# 3    66.0       1
# 4    42.0       2

# %%
import re 

def cleanup(text):
    punctuation = '(:),'
    pattern = re.compile(punctuation)
    text_subbed = re.sub(pattern, '', text)
    text_subbed = text_subbed.replace('\n',' ')
    text_subbed = text_subbed.replace('"',' ')
    text_subbed = text_subbed.replace("'",' ')
    return text_subbed

# %%
trainstr = train.Titulo.to_string(index = False) + train.PrimeiroParag.to_string(index = False)
teststr = test.Titulo.to_string(index = False) + test.PrimeiroParag.to_string(index = False)

train_clean = cleanup(trainstr)
test_clean = cleanup(teststr)

train_list = train_clean.split()
test_list = test_clean.split()

# %%
# Separando por Target
train0 = train[train['Target']==0]
train1 = train[train['Target']==1]
train2 = train[train['Target']==2]

# %%
# Limpando
train0_clean = train0.Titulo.apply(cleanup)
train1_clean = train1.Titulo.apply(cleanup)
train2_clean = train2.Titulo.apply(cleanup)

# %%
# Transformando em string
str_train0 = train0_clean.to_string(index = False)
str_train1 = train1_clean.to_string(index = False)
str_train2 = train2_clean.to_string(index = False)
str_train = list_train0 + list_train1 + list_train2

# %%
# Transformando em lista
list_train0 = str_train0.split()
list_train1 = str_train1.split()
list_train2 = str_train2.split()
list_train = list_train0 + list_train1 + list_train2

list_train_norep = set(list_train)

# %%
# Frequência absoluta
fa_train0 = train0_clean.value_counts()
fa_train1 = train1_clean.value_counts()
fa_train2 = train2_clean.value_counts()
fa_train = pd.Series(list_train).value_counts()

# %%
# Probabilidades
prob0 = len(list_train0)/len(list_train)
prob1 = len(list_train1)/len(list_train)
prob2 = len(list_train2)/len(list_train)

# %%
# LaPlace
def LaPlace0(palavra):
    if palavra not in list_train0:
        x = 1 / (len(list_train0) + len(list_train_norep))
    else:
        x = fa_train0[palavra] / fa_train0.sum()
    return x

def LaPlace1(palavra):
    if palavra not in list_train1:
        x = 1 / (len(list_train1) + len(list_train_norep))
    else:
        x = fa_train1[palavra] / fa_train1.sum()
    return x

def LaPlace2(palavra):
    if palavra not in list_train2:
        x = 1 / (len(list_train2) + len(list_train_norep))
    else:
        x = fa_train2[palavra] / fa_train2.sum()
    return x

# %%
# # Naive Bayes
# def cprob0(noticia):
#     p = 1
#     for palavra in noticia:
#         p *= LaPlace0(palavra)
#     return p

# def cprob1(noticia):
#     p = 1
#     for palavra in noticia:
#         p *= LaPlace1(palavra)
#     return p

# def cprob2(noticia):
#     p = 1
#     for palavra in noticia:
#         p *= LaPlace2(palavra)
#     return p

# def NaiveBayes(noticia):
#     prob_not0 = cprob0(noticia)
#     prob_not1 = cprob1(noticia)
#     prob_not2 = cprob2(noticia)
    
#     prob_0not = prob_not0 * prob0
#     prob_1not = prob_not1 * prob1
#     prob_2not = prob_not2 * prob2
    
#     if prob_1not > prob_0not and prob_1not > prob_2not:
#         return 1
#     elif prob_2not > prob_1not and prob_2not > prob_0not:
#         return 2
#     else:
#         return 0

# %%
# Naive Bayes
def cprob0(palavra):
    p = 1
    p *= LaPlace0(palavra)
    return p

def cprob1(palavra):
    p = 1
    p *= LaPlace1(palavra)
    return p

def cprob2(palavra):
    p = 1
    p *= LaPlace2(palavra)
    return p

def NaiveBayes(noticia):
    prob_not0 = cprob0(noticia)
    prob_not1 = cprob1(noticia)
    prob_not2 = cprob2(noticia)
    
    prob_0not = prob_not0 * prob0
    prob_1not = prob_not1 * prob1
    prob_2not = prob_not2 * prob2
    
    if prob_1not > prob_0not and prob_1not > prob_2not:
        return 1
    elif prob_2not > prob_1not and prob_2not > prob_0not:
        return 2
    else:
        return 0

# %%
performer = test.copy()

performer['clean'] = performer.Titulo.apply(cleanup)
performer['comp'] = performer.clean.apply(NaiveBayes)

performer.head(5)
# Out:
#                Categoria                                             Titulo  \
# 0              Mercados   Ibovespa (IBOV) vira para queda, com VALE3 ent...
# 1              Empresas   Ação da Braskem (BRKM3) avança com notícia sob...
# 2              Mercados   Compre commodities, se preocupe com recessão d...
# 3  Carteira Recomendada   Veja as 5 novas ações escaladas pela XP para e...
# 4            Mais Lidas   Respostas sobre Magazine Luiza (MGLU3) e mais ...
#
#                                        PrimeiroParag                Data  \
# 0  O Ibovespa (IBOV) operava sem forças nesta qua...  24/08/2022 - 13:58
# 1  As ações da Braskem (BRKM3) avançavam ao redor...  02/09/2022 - 11:30
# 2  O Goldman Sachs recomenda que os investidores ...   29/08/2022 - 9:49
# 3  A XP Investimentos repaginou sua carteira reco...   20/08/2022 - 9:31
# 4  Investidores não tiraram Magazine Luiza (MGLU3...  28/08/2022 - 10:30
#
#    Pagina  Target                                              clean  comp
# 0    53.0       2  Ibovespa (IBOV) vira para queda, com VALE3 ent...     1
# 1    20.0       2  Ação da Braskem (BRKM3) avança com notícia sob...     1
# 2    40.0       1  Compre commodities, se preocupe com recessão d...     1
# 3    66.0       1  Veja as 5 novas ações escaladas pela XP para e...     1
# 4    42.0       2  Respostas sobre Magazine Luiza (MGLU3) e mais ...     1

# %%
for titulo in performer.Titulo:
    titulo = titulo.split()
# Out:
# ['Ibovespa', '(IBOV)', 'vira', 'para', 'queda,', 'com', 'VALE3', 'entre', 'as', 'maiores', 'perdas']
#
#  aaaaa
#
# ['Ação', 'da', 'Braskem', '(BRKM3)', 'avança', 'com', 'notícia', 'sobre', 'controle;', 'Citi', 'eleva', 'para', '‘compra’']
#
#  aaaaa
#
# ['Compre', 'commodities,', 'se', 'preocupe', 'com', 'recessão', 'depois,', 'diz', 'Goldman']
#
#  aaaaa
#
# ['Veja', 'as', '5', 'novas', 'ações', 'escaladas', 'pela', 'XP', 'para', 'enfrentar', 'o', 'Ibovespa', 'nos', 'próximos', 'dias']
#
#  aaaaa
#
# ['Respostas', 'sobre', 'Magazine', 'Luiza', '(MGLU3)', 'e', 'mais', 'destaques', 'de', 'Comprar', 'ou', 'Vender', 'da', 'última', 'semana']
#
#  aaaaa
#
# ['Como', 'o', 'conflito', 'no', 'Iraque', 'pode', 'impactar', 'Petrobras', '(PETR4)', 'e', 'PRIO']
#
#  aaaaa
#
# ['Uma', 'das', 'empreendedoras', 'de', 'maior', 'impacto', 'na', 'América', 'Latina,', 'Gisele', 'Paula', 'revela', 'o', 'segredo', 'para', 'deixar', 'clientes', 'felizes']
#
#  aaaaa
#
# ['Santander', 'escala', 'Petrobras', '(PETR4),', 'Vale', '(VALE3)', 'e', 'outras', 'ações', 'de', 'peso', 'para', 'carteira', 'de', 'setembro']
#
#  aaaaa
#
# ['Bolsonaro', 'indica', 'que', 'pode', 'haver', 'mudança', 'na', 'política', 'econômica,', 'mas', 'reforça', 'confiança', 'em', 'Guedes']
#
#  aaaaa
#
# ['Sob', 'Lula,', 'Petrobras', '(PETR4)', 'buscaria', 'expandir', 'energia', 'renovável', 'e', 'refino']
#
#  aaaaa
#
# ['IRB', '(IRBR3)', 'lança', 'oferta', 'de', 'ações']
#
#  aaaaa
#
# ['Ibovespa', '(IBOV)', 'opera', 'em', 'alta', 'nesta', 'segunda-feira', '(5)']
#
#  aaaaa
#
# ['Ações', 'europeias', 'se', 'recuperam', 'após', 'início', 'de', 'semana', 'difícil']
#
#  aaaaa
#
# ['STF', 'decide', 'que', 'MP', 'não', 'tem', 'competência', 'exclusiva', 'para', 'propor', 'ações', 'de', 'improbidade']
#
#  aaaaa
#
# ['Pesquisa', 'inédita:', '57%', 'da', 'força', 'de', 'trabalho', 'brasileira', 'terá', 'mais', 'de', '45', 'anos', 'em', '2040,', 'mas', 'poucas', 'empresas', 'estão', 'se', 'preparando']
#
#  aaaaa
#
# ['Banco', 'do', 'Brasil', '(BBAS3)', 'ou', 'Bradesco', '(BBDC4)?', 'Veja', 'qual', 'a', 'melhor', 'ação', 'para', 'investir', 'em', 'setembro,', 'segundo', 'o', 'Safra']
#
#  aaaaa
#
# ['Pré-Mercado:', 'Uma', 'semana', 'difícil']
#
#  aaaaa
#
# ['Porsche', 'atrai', 'demanda', 'de', 'IPO', 'em', 'valuation', 'de', 'até', 'US$', '85', 'bilhões']
#
#  aaaaa
#
# ['SLC', 'Agrícola', '(SLCE3):', 'Os', 'dois', 'principais', 'riscos', 'que', 'impedem', 'a', 'compra', 'da', 'ação,', 'segundo', 'Ativa']
#
#  aaaaa
#
# ['Magazine', 'Luiza', '(MGLU3),', 'Via', '(VIIA3)', 'e', 'outras', 'ações', 'que', 'ganham', 'com', 'a', 'queda', 'da', 'inflação;', 'veja', 'a', 'lista']
#
#  aaaaa
#
# ['Selic', 'a', '14%', 'ao', 'ano', 'e', 'choque', 'de', 'realidade', 'de', 'Campos', 'Neto', 'são', 'bons', 'para', 'a', 'renda', 'fixa']
#
#  aaaaa
#
# ['Com', 'retomada', 'do', 'varejo,', 'é', 'momento', 'de', 'esquecer', 'Magazine', 'Luiza', '(MGLU3)', 'e', 'dar', 'uma', 'chance', 'à', 'Via', '(VIIA3)?']
#
#  aaaaa
#
# ['Pré-Mercado:', 'As', 'tão', 'aguardadas', 'falas', 'de', 'Powell']
#
#  aaaaa
#
# ['Ibovespa', '(IBOV)', 'opera', 'em', 'queda', 'nesta', 'segunda-feira', '(22)']
#
#  aaaaa
#
# ['IRB', '(IRBR3):', 'Veja', 'os', '10', 'fundos', 'com', 'maior', 'posição', 'vendida']
#
#  aaaaa
#
# ['Tesla', '(TSLA):', 'Musk', 'quer', 'atrair', 'pequenos', 'investidores', 'para', 'comprar', 'ação', 'da', 'empresa']
#
#  aaaaa
#
# ['Cielo', '(CIEL3):', 'Consenso', 'ainda', 'está', 'conservador,', 'diz', 'BTG;', 'analistas', 'veem', '“grandes', 'riscos', 'positivos”']
#
#  aaaaa
#
# ['Confira', 'as', 'principais', 'notícias', 'dos', 'jornais', 'nesta', 'quarta-feira']
#
#  aaaaa
#
# ['Coluna', 'do', 'TradingView:', 'Bolsa', 'segue', 'mau', 'humor', 'externo']
#
#  aaaaa
#
# ['Relatório', 'da', 'Casa', 'Branca', 'indica', 'possíveis', 'restrições', 'à', 'mineração', 'cripto', 'proof-of-work']
#
#  aaaaa
#
# ['Magazine', 'Luiza', '(MGLU3)', 'dispara', '66%', 'e', 'é', 'destaque', 'em', 'agosto;', 'vem', 'mais', 'alta', 'por', 'aí?']
#
#  aaaaa
#
# ['Renda', 'fixa', '‘reinventada’', 'de', '200%', 'do', 'CDI?', 'Veja', 'onde', 'encontrar', 'os', 'melhores', '‘títulos’']
#
#  aaaaa
#
# ['BC', 'corrige', 'rota', 'para', 'Selic', 'e', 'mercado', 'reage', 'com', 'disparada', 'do', 'juro,', 'rali', 'do', 'dólar', 'e', 'queda', 'da', 'bolsa']
#
#  aaaaa
#
# ['Vamos', '(VAMO3):', 'XP', 'eleva', 'preço-alvo', 'a', 'R$', '21;', 'ações', 'ainda', 'podem', 'subir', 'mais', 'de', '40%']
#
#  aaaaa
#
# ['IPO', 'da', 'Porsche', 'tem', 'grande', 'interesse,', 'diz', 'CEO']
#
#  aaaaa
#
# ['Day', 'Trade:', 'Weg', '(WEGE3),', 'Eletrobras', '(ELET6)', 'e', 'mais', '6', 'ações', 'para', 'vender', 'hoje', 'e', 'buscar', 'até', '3,79%']
#
#  aaaaa
#
# ['Ampliação', 'do', 'novo', 'Bolsa', 'Família', 'prometida', 'por', 'Lula', 'pode', 'custar', 'R$', '18', 'bi', 'por', 'ano', 'e', 'não', 'será', 'imediata']
#
#  aaaaa
#
# ['Ibovespa', 'pode', 'realizar', 'lucros', 'com', 'marasmo', 'no', 'exterior', 'e', 'Ásia', 'acumula', 'queda']
#
#  aaaaa
#
# ['Ibovespa', '(IBOV)', 'opera', 'entre', 'altas', 'e', 'baixas', 'com', 'Nova', 'York', 'e', 'realização', 'de', 'lucros']
#
#  aaaaa
#
# ['AMER3', 'salta', '22%', 'e', 'é,', 'de', 'longe,', 'destaque', 'positivo', 'do', 'Ibovespa;', 'PETZ3', 'cai', '7%']
#
#  aaaaa
#
# ['Oi', '(OIBR3)', 'e', 'outras', 'empresas', 'para', 'ficar', 'de', 'olho', 'hoje']
#
#  aaaaa
#
# ['Magazine', 'Luiza', '(MGLU3):', 'Gestoras', 'hesitam', 'em', 'comprar', 'ação;', '“Precisa', 'entregar', 'mais”,', 'sustentam']
#
#  aaaaa
#
# ['Ibovespa:', 'PRIO3', 'avança', 'mais', 'de', '6%', 'e', 'PCAR3', 'salta', 'quase', '10%;', 'IRBR3', 'fecha', 'valendo', 'R$', '1,20']
#
#  aaaaa
#
# ['Ibovespa:', 'ALPA4', 'estende', 'os', 'ganhos', 'e', 'é', 'o', 'destaque', 'de', 'alta;', 'NTCO3', 'está', 'na', 'ponta', 'negativa']
#
#  aaaaa
#
# ['Totvs', '(TOTS3):', 'Aquisição', 'da', 'RBM', 'é', 'positiva,', 'e', 'ações', 'avançam', '2,6%']
#
#  aaaaa
#
# ['Investidores', 'não', 'veem', 'guinada', 'do', 'Fed', 'e', 'se', 'preparam', 'para', 'mensagem', '“hawkish”', 'de', 'Powell', 'em', 'Jackson', 'Hole']
#
#  aaaaa
#
# ['Funcionários', 'e', 'fornecedores', 'da', 'Cemig', '(CMIG4)', 'são', 'alvo', 'de', 'operação', 'policial', 'e', 'do', 'MP']
#
#  aaaaa
#
# ['Petróleo', 'sobe', 'na', 'quinta-feira,', 'com', 'aviso', 'de', 'Putin', 'e', 'menor', 'ritmo', 'de', 'produção', 'nos', 'EUA']
#
#  aaaaa
#
# ['Ação', 'do', 'setor', 'de', 'alimentos', 'pode', 'dobrar', 'de', 'valor', 'na', 'Bolsa,', 'segundo', 'analista']
#
#  aaaaa
#
# ['Adeus,', 'Apple:', 'analista', 'brasileiro', 'que', 'entregou', '360%', 'do', 'Ibovespa', 'tem', 'nova', 'aposta', 'para', 'setembro:', 'uma', 'ação', 'brasileira', 'de', 'tecnologia']
#
#  aaaaa
#
# ['Credit', 'Suisse', 'reestrutura', '1°', 'escalão', 'e', 'contrata', 'ex-Deutsche', 'Bank', 'como', 'diretor', 'financeiro']
#
#  aaaaa
#
# ['AENA', 'leva', 'bloco', 'de', 'Congonhas', 'no', 'leilão', 'de', 'aeroportos', 'da', 'ANAC', 'por', 'R$', '2,450', 'bilhões']
#
#  aaaaa
#
# ['Ibovespa', '(IBOV)', 'opera', 'em', 'alta', 'nesta', 'sexta-feira', '(2)']
#
#  aaaaa
#
# ['Ações', 'europeias', 'sobem', 'após', '5', 'dias', 'de', 'perdas,', 'mas', 'ainda', 'registram', 'queda', 'semanal']
#
#  aaaaa
#
# ['Ações', 'europeias', 'fecham', 'semana', 'em', 'baixa', 'por', 'temores', 'de', 'recessão']
#
#  aaaaa
#
# ['Confira', 'as', 'principais', 'notícias', 'dos', 'jornais', 'nesta', 'terça-feira']
#
#  aaaaa
#
# ['Ações', 'para', 'setembro:', 'Varejista', 'está', 'perto', 'de', 'tirar', 'Vale', '(VALE3)', 'do', 'posto', 'de', 'preferida', 'dos', 'analistas']
#
#  aaaaa
#
# ['Fluxo', 'de', 'capital', 'externo', 'para', 'bolsa', 'brasileira', 'melhora,', 'mas', 'há', 'duvidas', 'sobre', 'manutenção']
#
#  aaaaa
#
# ['Ação', 'do', 'agronegócio', 'pode', 'disparar', '83%', 'e', 'ainda', 'está', 'recheada', 'de', 'dividendos']
#
#  aaaaa
#
# ['PRIO', '(PRIO3)', 'e', 'Dommo', '(DMMO3)', 'recuam', 'em', 'meio', 'à', 'notícia', 'sobre', 'possível', 'aquisição']
#
#  aaaaa
#
# ['Americanas', '(AMER3)', 'salta', '15%', 'e', 'volta', 'a', 'ter', 'o', 'melhor', 'desempenho', 'do', 'Ibovespa']
#
#  aaaaa
#
# ['Petz', '(PETZ3),', 'Unipar', '(UNIP6)', 'e', 'outras', 'novidades:', 'Veja', 'as', 'small', 'caps', 'para', 'ter', 'em', 'setembro,', 'segundo', 'a', 'Genial']
#
#  aaaaa
#
# ['Day', 'Trade:', '9', 'ações', 'para', 'vender', 'hoje', 'e', 'buscar', 'até', '3,73%,', 'segundo', 'Ágora,', 'BTG', 'e', 'PagBank']
#
#  aaaaa
#
# ['Jorge', 'Paulo', 'Lemann', 'volta', 'a', 'ser', 'o', 'mais', 'rico', 'do', 'Brasil:', 'Veja', 'os', '10', 'maiores', 'bilionários', 'do', 'país']
#
#  aaaaa
#
# ['Vale', '(VALE3),', 'Taurus', '(TASA4)', 'e', 'mais', '3', 'ações', 'para', 'buscar', 'retornos', 'de', 'até', '8,4%', 'na', 'semana,', 'segundo', 'MyCap']
#
#  aaaaa
#
# ['Ibovespa:', 'PRIO3', 'lidera', 'as', 'altas;', 'HAPV3', 'é', 'o', 'destaque', 'negativo']
#
#  aaaaa
#
# ['Não', 'é', 'possível', 'usucapião', 'em', 'imóvel', 'de', 'instituição', 'financeira,', 'decide', 'STJ']
#
#  aaaaa
#
# ['Just', 'Eat', 'vende', 'fatia', 'no', 'iFood', 'para', 'Prosus', 'por', 'US$', '1,8', 'bi']
#
#  aaaaa
#
# ['Shopee', 'corta', 'dezenas', 'de', 'vagas', 'dias', 'antes', 'de', 'funcionários', 'iniciarem', 'na', 'empresa,', 'diz', 'Reuters']
#
#  aaaaa
#
# ['M.', 'Dias', 'Branco', '(MDIA3)', 'conclui', 'parceria', 'de', 'geração', 'de', 'energia', 'eólica', 'com', 'Omega', '(MEGA3)']
#
#  aaaaa
#
# ['Banco', 'do', 'Brasil', '(BBAS3):', 'o', 'desconto', 'para', 'ITUB4', 'e', 'BBDC4', 'ainda', 'é', 'justificado?']
#
#  aaaaa
#
# ['Magazine', 'Luiza', '(MGLU3):', 'Após', 'ação', 'disparar', '111%,', 'qual', 'é', 'o', 'próximo', 'alvo?']
#
#  aaaaa
#
# ['Cresce', 'a', 'procura', 'por', 'profissionais', 'de', 'ESG', 'no', 'agronegócio;', 'veja', 'os', 'cargos', 'em', 'alta', 'e', 'a', 'média', 'salarial']
#
#  aaaaa
#
# ['Dólar', 'opera', 'em', 'queda', 'em', 'dia', 'de', 'Jackson', 'Hole;', 'Ibovespa', 'futuro', 'sobe']
#
#  aaaaa
#
# ['Americanas', '(AMER3)', 'e', 'Google', 'fecham', 'parceria', 'com', 'foco', 'em', 'inovação']
#
#  aaaaa
#
# ['Prejuízo', 'líquido', 'da', 'Stone', '(STNE)', 'assusta', 'investidores', 'e', 'ações', 'da', 'fintech', 'desabam', '27%', 'na', 'Nasdaq']
#
#  aaaaa
#
# ['Porto', 'Seguro', '(PPSA3)', 'sobe', '1,5%', 'após', 'anunciar', 'R$', '397', 'milhões', 'em', 'JCP']
#
#  aaaaa
#
# ['Day', 'Trade:', '9', 'ações', 'para', 'vender', 'nesta', 'quinta', 'e', 'buscar', 'até', '3,95%,', 'segundo', 'Ágora,', 'BTG', 'e', 'PagBank']
#
#  aaaaa
#
# ['Itaú', 'Unibanco', '(ITUB4)', 'e', 'outras', 'empresas', 'para', 'ficar', 'de', 'olho', 'hoje']
#
#  aaaaa
#
# ['JPMorgan', 'afirma', 'que', 'receita', 'da', 'Coinbase', '(COIN)', 'pode', 'gerar', 'mais', 'de', 'US$', '650', 'mi', 'após', 'The', 'Merge']
#
#  aaaaa
#
# ['Oi', '(OIBR3)', 'confirma', 'venda', 'de', 'operação', 'fixa', 'por', 'até', 'R$', '1,7', 'bilhão', 'e', 'se', 'aproxima', 'do', 'fim', 'da', 'recuperação', 'judicial,', 'mas', 'CEO', 'da', 'Empiricus', 'não', 'vê', 'retomada', 'para', 'ação', 'e', 'recomenda', 'investir', 'em', '‘barganha’', 'do', 'Ibovespa', 'no', 'lugar']
#
#  aaaaa
#
# ['Três', 'notícias', 'puxam', 'alta', 'de', '4%', 'do', 'petróleo', 'só', 'hoje']
#
#  aaaaa
#
# ['Ibovespa', '(IBOV)', 'sobe', 'na', 'abertura,', 'em', 'linha', 'com', 'exterior']
#
#  aaaaa
#
# ['Small', 'caps:', '13', 'ações', 'com', 'potencial', 'para', 'entregar', 'retorno', 'em', 'setembro,', 'segundo', 'Elite']
#
#  aaaaa
#
# ['Dólar', 'teve', 'impactos', 'positivos', 'e', 'negativos', 'em', 'empresas', 'no', '2T22;', 'entenda']
#
#  aaaaa
#
# ['Fertilizantes', 'Heringer', 'avalia', 'AGE', 'para', 'deliberar', 'preço', 'de', 'oferta', 'proposta', 'pela', 'Eurochem']
#
#  aaaaa
#
# ['BB', 'Seguridade', '(BBSE3)', 'aumenta', 'desafio', 'do', 'IRB', '(IRBR3),', 'diz', 'BTG']
#
#  aaaaa
#
# ['Petróleo', 'tem', 'sessão', 'volátil', 'e', 'termina', 'dia', '‘de', 'lado”']
#
#  aaaaa
#
# ['Ibovespa', 'volta', 'de', 'feriado', 'e', 'Japão', 'salta', 'mais', 'de', '2%,', 'liderando', 'ganhos', 'na', 'Ásia']
#
#  aaaaa
#
# ['Day', 'Trade:', 'Eletrobras', '(ELET3),', 'Usiminas', '(USIM5)', 'e', 'mais', '6', 'ações', 'para', 'comprar', 'hoje', 'e', 'buscar', 'até', '3,30%']
#
#  aaaaa
#
# ['Quando', 'as', 'criptomoedas', 'vão', 'voltar', 'a', 'subir?', '3', 'fatores', 'decisivos', 'para', 'o', 'rumo', 'do', 'Bitcoin', '(BTC),', 'segundo', 'casa', 'análise']
#
#  aaaaa
#
# ['CEO', 'da', 'Empiricus', 'explica', 'por', 'que', 'decidiu', 'manter', 'posição', 'vendida', 'em', 'Nubank', '(NUBR33)', 'após', 'o', 'resultado', 'aparentemente', 'positivo', 'no', 'balanço', 'do', '2T22', '–', 'e', 'recomenda', 'que', 'investidores', 'façam', 'o', 'mesmo']
#
#  aaaaa
#
# ['Escritórios', 'do', 'JPMorgan', 'na', 'Alemanha', 'são', 'alvo', 'de', 'busca', 'em', 'caso', 'de', 'escândalo', 'financeiro']
#
#  aaaaa
#
# ['Elétricas', 'vão', 'às', 'compras:', 'Eneva', '(ENEV3)', 'e', 'Cemig', '(CMIG4)', 'sobem', 'após', 'novas', 'aquisições']
#
#  aaaaa
#
# ['Day', 'Trade:', 'Eletrobras', '(ELET6),', '3R', 'Petroleum', '(RRRP3)', 'e', 'mais', '5', 'ações', 'para', 'comprar', 'hoje', 'e', 'buscar', 'até', '3,76%']
#
#  aaaaa
#
# ['Quer', 'investir', 'em', 'petróleo?', 'Não', 'compre', 'PetroRio', '(PRIO3)', 'e', 'nem', 'PetroReconcavo', '(RECV3):', 'analista', 'encontra', 'ação', 'de', 'petroleira', 'verdadeiramente', 'promissora', 'que', 'pode', 'valorizar', '100%']
#
#  aaaaa
#
# ['Day', 'Trade:', 'Banco', 'do', 'Brasil', '(BBAS3),', 'Bradesco', '(BBDC3)', 'e', 'mais', '7', 'ações', 'para', 'vender', 'hoje,', 'segundo', 'Ágora,', 'BTG', 'e', 'PagBank']
#
#  aaaaa
#
# ['Ibovespa:', 'GOLL4', 'e', 'AZUL4', 'estendem', 'os', 'ganhos', 'e', 'sobem', 'mais', 'de', '6%;', 'Petrobras', 'está', 'na', 'ponta', 'negativa']
#
#  aaaaa
#
# ['7', 'de', 'setembro:', 'o', 'que', 'esperar', 'da', 'Bolsa', 'após', 'ida', 'de', 'Bolsonaro', 'às', 'ruas', 'junto', 'com', 'empresários', 'e', 'partidários']
#
#  aaaaa
#
# ['JBS', '(JBSS3)', 'tem', 'preço-alvo', 'cortado', 'com', 'restrição', 'de', 'gado', 'nos', 'EUA;', 'veja', 'o', 'que', 'fazer']
#
#  aaaaa
#
# ['O', 'que', 'esperar', 'de', 'Taesa', '(TAEE11)', 'após', 'crescimento', 'em', 'meio', 'à', 'alta', 'da', 'inflação?']
#
#  aaaaa
#
# ['Confira', 'as', 'principais', 'notícias', 'dos', 'jornais', 'nesta', 'quinta-feira']
#
#  aaaaa
#
# ['O', 'que', 'fazer', 'com', 'os', 'dividendos', 'de', 'Petrobras', '(PETR4)', 'e', 'Vale', '(VALE3)?']
#
#  aaaaa
#
# ['Biruta', 'dos', 'mercados', 'deixa', 'soja', 'e', 'milho', 'com', 'sinais', 'trocados;', 'só', 'trigo', 'está', 'no', 'seu', 'quadrado']
#
#  aaaaa
#
# ['O', 'governo', 'tem', 'uma', 'dívida', 'bilionária', 'com', 'os', 'brasileiros', 'e', 'você', 'pode', 'lucrar', 'com', 'isso,', 'fora', 'do', 'Tesouro', 'Direto;', 'entenda']
#
#  aaaaa
#
# ['Ibovespa:', 'LWSA3', 'e', 'MGLU3', 'estão', 'entre', 'as', 'maiores', 'quedas', 'desta', 'sexta;', 'PETR4', 'despenca', '5%']
#
#  aaaaa
#
# ['Ações', 'do', 'agro', 'são', 'destaque', 'entre', 'recomendações', 'do', 'BB', 'para', 'a', 'semana']
#
#  aaaaa
#
# ['5', 'ações', 'para', 'investir', 'na', 'semana', 'e', 'bater', 'o', 'Ibovespa,', 'segundo', 'a', 'Ativa']
#
#  aaaaa
#
# ['Ibovespa', '(IBOV)', 'opera', 'entre', 'perdas', 'e', 'ganhos', 'antes', 'da', 'ata', 'do', 'banco', 'central', 'dos', 'EUA']
#
#  aaaaa
#
# ['VALE3,', 'NU,', 'NTCO3,', 'CASH3:', 'os', 'piores', 'resultados', 'da', 'bolsa,', 'segundo', 'o', 'BBA']
#
#  aaaaa
#
# ['10', 'ações', 'para', 'já', 'se', 'posicionar', 'e', 'lucrar', 'em', 'setembro,', 'segundo', 'Ágora']
#
#  aaaaa
#
# ['Inter', '(INBR31):', 'Bradesco', 'BBI', 'vê', 'alta', 'de', 'mais', 'de', '90%', 'para', 'ação']
#
#  aaaaa
#
# ['Dommo', '(DMMO3),', 'IRB', '(IRBR3)', 'e', 'outras', 'empresas', 'para', 'ficar', 'de', 'olho', 'hoje']
#
#  aaaaa
#
# ['BTG', 'Pactual', '(BPAC11):', 'Um', 'dos', 'favoritos', 'do', 'Safra,', 'papel', 'tem', 'espaço', 'para', 'subir', 'mais', '30%']
#
#  aaaaa
#
# ['Na', 'sabatina', 'de', 'Lula', 'no', 'JN,', 'o', 'que', 'chamou', 'a', 'atenção', 'foi', 'a', 'postura', 'dos', 'entrevistadores']
#
#  aaaaa
#
# ['PETR4', 'e', 'mais', 'ações', 'que', 'pagam', 'bons', 'dividendos:', 'Os', 'destaques', 'em', 'Comprar', 'ou', 'Vender', 'da', 'última', 'semana']
#
#  aaaaa
#
# ['China', 'deve', 'afrouxar', 'política', 'monetária', 'apesar', 'da', 'queda', 'do', 'yuan']
#
#  aaaaa
#
# ['Volkswagen', 'está', 'subvalorizada,', 'mas', 'negócio', 'de', 'baterias', 'pode', 'ajudar,', 'diz', '2°', 'maior', 'acionista']
#
#  aaaaa
#
# ['Dólar', 'abre', '1º', 'pregão', 'de', 'setembro', 'em', 'alta;', 'Ibovespa', 'futuro', 'opera', 'em', 'queda']
#
#  aaaaa
#
# ['5', 'ações', 'escolhidas', 'a', 'dedo', 'pela', 'Vitreo', 'para', 'superar', 'o', 'Ibovespa', 'semana', 'que', 'vem']
#
#  aaaaa
#
# ['Ibovespa', 'futuro', 'avança', 'na', 'volta', 'do', 'feriado', 'e', 'dólar', 'recua;', 'veja', 'o', 'que', 'move', 'o', 'dia']
#
#  aaaaa
#
# ['Receita', 'da', 'Baidu', 'cai', 'no', '2°', 'tri,', 'mas', 'supera', 'projeções', 'com', 'ajuda', 'de', 'serviços', 'de', 'nuvem']
#
#  aaaaa
#
# ['Dia', 'Internacional', 'do', 'Gamer:', 'IPO,', 'carreira', 'e', 'metaverso,', 'veja', 'o', 'que', 'movimenta', 'esse', 'universo']
#
#  aaaaa
#
# ['Usiminas', '(USIM5)', 'prevê', 'mais', 'investimentos', 'e', 'ações', 'caem;', 'Nova', 'política', 'de', 'dividendos', 'fica', 'mais', 'distante,', 'diz', 'Ativa']
#
#  aaaaa
#
# ['O', 'que', 'as', 'gestoras', 'em', 'ações', 'globais', 'estão', 'olhando', 'em', 'temas', 'de', 'investimentos']
#
#  aaaaa
#
# ['BRF', '(BRFS3):', 'Ex-CEO', 'da', 'Marfrig', '(MRFG3)', 'assume', 'comando', 'da', 'companhia']
#
#  aaaaa
#
# ['IMC', '(MEAL3):', 'Justiça', 'concede', 'nova', 'suspensão', 'do', 'procedimento', 'arbitral', 'envolvendo', 'contrato', 'com', 'KFC']
#
#  aaaaa
#
# ['Ações', 'europeias', 'caem', 'pelo', 'terceiro', 'dia', 'com', 'temores', 'de', 'juros', 'elevados', 'e', 'recessão', 'em', 'alta']
#
#  aaaaa
#
# ['Confira', 'as', 'principais', 'notícias', 'dos', 'jornais', 'nesta', 'sexta-feira']
#
#  aaaaa
#
# ['5', 'ações', 'para', 'lucrar', 'com', 'dividendos', 'em', 'setembro,', 'segundo', 'a', 'Planner']
#
#  aaaaa
#
# ['Brasil', 'registra', 'déficit', 'em', 'conta', 'corrente', 'de', 'US$', '3,5', 'bi', 'em', 'maio,', 'diz', 'BC']
#
#  aaaaa
#
# ['Esplanada', 'dos', 'Ministérios', 'amanhece', 'bloqueada', 'para', 'veículos']
#
#  aaaaa
#
# ['Vários', 'dividendos', 'na', 'mesma', 'empresa:', 'esta', '‘vaca', 'leiteira’', 'tem', 'muitas', '‘bezerras’', 'e', 'pode', 'subir', '52%']
#
#  aaaaa
#
# ['A', 'ação', 'de', 'petroleira', 'que', 'pode', 'saltar', '212%,', 'segundo', 'o', 'Itaú', 'BBA']
#
#  aaaaa
#
# ['Anitta', '‘se', 'livrou’', 'do', 'Nubank?', 'A', 'fintech', 'reportou', 'prejuízo', 'acima', 'do', 'consenso', 'no', '2T22', 'e', 'ação', 'NUBR33', '‘despenca’', 'mais', 'de', '10%', '–', 'CEO', 'da', 'Empiricus', 'recomenda', 'investir', 'apostando', 'na', 'queda;', 'entenda', 'como']
#
#  aaaaa
#
# ['O', 'vento', 'da', 'Aeris', '(AERI3)', '“vai', 'secar”?', 'BTG', 'corta', 'preço-alvo', 'em', '63%', 'e', 'vê', '“desafios”', 'para', 'energia', 'eólica']
#
#  aaaaa
#
# ['Rússia', 'diz', 'que', 'seus', 'bombardeiros', 'patrulham', 'o', 'Mar', 'do', 'Japão']
#
#  aaaaa
#
# ['Ibovespa', '(IBOV)', 'tomba', 'com', 'falas', 'de', 'Campos', 'Neto', 'sobre', 'juros;', 'commodities', 'e', 'bancos', 'pressionam']
#
#  aaaaa
#
# ['Prio', '(PRIO3)', 'conclui', 'emissão', 'de', 'R$', '2', 'bilhões', 'em', 'debêntures']
#
#  aaaaa
#
# ['Ucrânia', 'diz', 'ter', 'iniciado', 'ofensiva', 'contra', 'forças', 'russas', 'no', 'sul']
#
#  aaaaa
#
# ['Ibovespa', '(IBOV)', 'opera', 'em', 'queda,', 'com', 'baixa', 'em', 'NY']
#
#  aaaaa
#
# ['Se', 'cuida,', 'Vale', '(VALE3)!', 'Líder', 'de', 'infraestrutura', 'na', 'América', 'Latina', 'está', 'chegando', '“com', 'tudo”', 'no', 'setor', 'de', 'mineração', '–', 'e', 'você', 'pode', 'aproveitar', 'para', 'ganhar', 'dinheiro', 'com', 'isso']
#
#  aaaaa
#
# ['Retornos', 'de', 'até', '37%:', 'Veja', '8', 'ações', 'para', 'lucrar', 'com', 'dividendos,', 'segundo', 'a', 'Guide']
#
#  aaaaa
#
# ['Energias', 'do', 'Brasil', '(ENBR3)', 'dispara', '4,4%', 'após', 'venda', 'de', 'hidrelétrica,', 'especialistas', 'esperam', 'mais', 'dividendos']
#
#  aaaaa
#
# ['Isenção', 'de', 'IR', 'sobre', 'venda', 'de', 'ações', 'não', 'se', 'transfere', 'para', 'herdeiros,', 'define', 'STJ']
#
#  aaaaa
#
# ['Suzano', '(SUZB3):', 'Desempenho', 'da', 'ação', 'não', 'reflete', 'preços', 'da', 'celulose;', 'BTG', 'vê', 'grande', 'potencial']
#
#  aaaaa
#
# ['IRB', '(IRBR3)', 'ladeira', 'a', 'baixo', 'e', 'debate', 'presidencial', 'acalorado:', 'Veja', 'os', 'destaques', 'da', 'semana']
#
#  aaaaa
#
# ['Antiga', 'OGX', 'de', 'Eike', 'Batista,', 'Dommo', '(DMMO3)', 'volta', 'ao', 'radar', 'corporativo']
#
#  aaaaa
#
# ['Julius', 'Baer', 'compra', 'ação', 'com', 'cautela', 'antes', 'de', 'definição', 'eleitoral']
#
#  aaaaa
#
# ['Americanas', '(AMER3)', 'e', 'Magazine', 'Luiza', '(MGLU3)', 'disparam', 'mais', '20%', 'na', 'semana;', 'IRB', '(IRBR3)', 'lidera', 'ponta', 'negativa', 'do', 'Ibovespa']
#
#  aaaaa
#
# ['Ação', 'de', 'petroleira', 'é', 'a', 'mais', 'indicada', 'da', 'semana;', 'veja', 'o', 'melhor', 'de', '10', 'carteiras']
#
#  aaaaa
#
# ['3', 'cenários', 'possíveis', 'para', 'a', 'economia', 'global', 'e', 'como', 'investir', 'em', 'cada', 'um']
#
#  aaaaa
#
# ['Magazine', 'Luiza', '(MGLU3):', 'Cara', 'ou', 'barata?', 'Fundo', 'do', 'poço?', 'Vai', 'voltar', 'aos', 'R$', '27?', 'Veja', '5', 'respostas', 'para', 'ação']
#
#  aaaaa
#
# ['Day', 'Trade:', '9', 'ações', 'para', 'vender', 'hoje', 'e', 'buscar', 'lucro', 'de', 'até', '3,43%,', 'segundo', 'Ágora,', 'BTG', 'e', 'PagBank']
#
#  aaaaa
#
# ['NY:', 'S&P', 'e', 'Dow', 'têm', 'pior', 'queda', 'em', '2', 'meses;', 'mercado', 'recalibra', 'expectativas', 'sobre', 'aperto', 'monetário']
#
#  aaaaa
#
# ['Confira', '5', 'ações', 'para', 'investir', 'agora', 'e', 'lucrar', 'nos', 'próximos', 'dias,', 'segundo', 'BTG']
#
#  aaaaa
#
# ['Itaú', '(ITUB4),', 'Taesa', '(TAEE11)', 'e', 'o', 'top', '5', 'dividendos', 'para', 'setembro,', 'segundo', 'Genial']
#
#  aaaaa
#
# ['Petrobras', '(PETR4),', 'Vale', '(VALE3)', 'e', 'mais', '8', 'ações', 'para', 'buscar', 'lucro', 'diferenciado', 'no', 'curto', 'prazo,', 'segundo', 'Mirae']
#
#  aaaaa
#
# ['Aeris', '(AERI3)', 'já', 'caiu', 'demais;', 'Hora', 'de', 'comprar,', 'diz', 'XP']
#
#  aaaaa
#
# ['Cielo', '(CIEL3)', 'merece', 'o', 'benefício', 'da', 'dúvida;', 'Credit', 'Suisse', 'eleva', 'recomendação', 'e', 'vê', 'potencial', 'de', 'alta', 'de', '30%']
#
#  aaaaa
#
# ['BB', 'Seguridade', '(BBSE3):', 'Ação', 'já', 'chegou', 'no', 'topo,', 'diz', 'Bradesco', 'BBI']
#
#  aaaaa
#
# ['Confira', 'as', 'principais', 'notícias', 'dos', 'jornais', 'nesta', 'sexta-feira']
#
#  aaaaa
#
# ['Confira', 'as', 'principais', 'notícias', 'dos', 'jornais', 'nesta', 'quinta-feira']
#
#  aaaaa
#
# ['Itaúsa', '(ITSA4)', 'substitui', 'Banco', 'do', 'Brasil', '(BBAS3)', 'na', 'carteira', 'de', 'dividendos', 'do', 'Terra', 'para', 'setembro']
#
#  aaaaa
#
# ['Michelle', 'decide', '“mergulhar”', 'em', 'campanha', 'de', 'Bolsonaro', 'e', 'deve', 'ajudar', 'na', 'batalha', 'religiosa']
#
#  aaaaa
#
# ['Os', 'melhores', 'investimentos', 'tirados', 'de', '98', 'carteiras', 'para', 'setembro']
#
#  aaaaa
#
# ['O', 'céu', 'é', 'o', 'limite?', 'Petrobras', '(PETR4)', 'sobe', 'e', 'analista', 'crava:', 'ainda', 'está', 'barata']
#
#  aaaaa
#
# ['Ibovespa:', 'Entenda', 'por', 'que', 'dá', 'para', 'acreditar', 'que', '‘maré', 'boa’', 'vai', 'continuar', 'nos', 'próximos', 'meses']
#
#  aaaaa
#
# ['Petroleira', 'menor', 'desbanca', 'Petrobras', '(PETR4)', 'e', 'vira', 'preferência', 'de', 'Itaú', 'BBA;', 'veja', '18', 'papéis', 'para', 'setembro']
#
#  aaaaa
#
# ['Voluntariado:', 'Qual', 'a', 'importância', 'do', 'serviço', 'social', 'para', 'a', 'sua', 'carreira?']
#
#  aaaaa
#
# ['400%', 'de', 'valorização', 'em', 'apenas', 'uma', 'tacada:', 'criptomoeda', 'está', '‘programada’', 'para', 'decolar', 'depois', 'do', 'dia', '15', 'com', 'chance', 'de', 'fazer', 'R$', '1.000', 'virarem', 'R$', '5.000']
#
#  aaaaa
#
# ['Zoom', 'corta', 'previsões', 'para', '2022,', 'por', 'queda', 'da', 'demanda']
#
#  aaaaa
#
# ['Ações', 'europeias', 'iniciam', 'setembro', 'com', 'fraqueza', 'diante', 'de', 'temores', 'sobre', 'alta', 'de', 'juros']
#
#  aaaaa
#
# ['Ibovespa', '(IBOV)', 'cai', 'e', 'retoma', 'os', '110', 'mil', 'pontos', 'com', 'cautela', 'sobre', 'próximos', 'passos', 'do', 'Fed']
#
#  aaaaa
#
# ['Por', 'que', 'Vale', '(VALE3)', 'é', 'a', 'melhor', 'pagadora', 'de', 'dividendos', 'pelo', '5º', 'mês,', 'segundo', '22', 'analistas?']
#
#  aaaaa
#
# ['Energisa', '(ENGI11)', 'pagará', 'R$', '472,19', 'milhões', 'em', 'dividendos', 'intercalares']
#
#  aaaaa
#
# ['Ele', 'já', 'fez', 'o', 'dinheiro', 'de', 'quem', 'o', 'escutou', 'multiplicar', 'por', '9', 'vezes;', 'agora,', 'revelou', 'os', '10', 'investimentos', 'em', 'criptomoedas', 'que', 'você', 'precisa', 'ter', 'ainda', 'hoje', 'no', 'seu', 'portfólio']
#
#  aaaaa
#
# ['Para', 'onde', 'deve', 'olhar', 'o', 'empreendedor?']
#
#  aaaaa
#
# ['Maré', 'positiva', 'para', 'Magazine', 'Luiza', '(MGLU3)', 'e', 'venda', 'da', 'ex-OGX', 'de', 'Eike', 'Batista:', 'Veja', 'os', 'destaques', 'da', 'semana']
#
#  aaaaa
#
# ['Fundos', 'cripto', 'alavancados', 'permitirão', 'apostar', 'em', 'mercado', 'volátil']
#
#  aaaaa
#
# ['Ibovespa', 'pode', 'acompanhar', 'virada', 'em', 'NY', 'e', 'se', 'descolar', 'de', 'pregão', 'negativo', 'na', 'Ásia']
#
#  aaaaa
#
# ['Confira', 'as', 'principais', 'notícias', 'dos', 'jornais', 'nesta', 'segunda-feira']
#
#  aaaaa
#
# ['Ibovespa:', 'USIM5', 'dispara', 'mais', 'de', '8%', 'e', 'lidera', 'as', 'altas;', 'POSI3', 'é', 'destaque', 'de', 'queda']
#
#  aaaaa
#
# ['Bolsas', 'de', 'NY', 'abrem', 'em', 'queda,', 'ainda', 'sob', 'impacto', 'da', 'fala', 'de', 'Powell']
#
#  aaaaa
#
# ['Ibovespa', '(IBOV)', 'cai', 'na', 'abertura,', 'em', 'dia', 'fraco', 'no', 'exterior']
#
#  aaaaa
#
# ['Day', 'Trade:', 'Taurus', '(TASA4),', 'Weg', '(WEGE3)', 'e', 'mais', '6', 'ações', 'para', 'vender', 'nesta', 'terça', 'e', 'buscar', 'até', '3,07%']
#
#  aaaaa
#
# ['Ibovespa:', 'Por', 'que', 'AMER3', 'dispara', 'mais', 'de', '20%?', 'PETZ3', 'é', 'o', 'destaque', 'negativo']
#
#  aaaaa
#
# ['PagSeguro', '(PAGS)', 'e', 'Cielo', '(CIEL3)', 'relegam', 'desafios', 'no', 'setor', 'de', 'meio', 'de', 'pagamentos', 'após', 'balanços', 'do', '2T22']
#
#  aaaaa
#
# ['‘Aposentadoria', 'antecipada’:', 'analista', 'abre', 'técnica', 'que', 'pode', 'antecipar', 'pagamentos', 'equivalentes', 'ao', 'teto', 'do', 'INSS', '(R$', '7.087,22)']
#
#  aaaaa
#
# ['Tim', 'Brasil', '(TIMS3)', 'recua', 'com', 'partido', 'líder', 'nas', 'eleições', 'italianas', 'sinalizando', 'venda', 'da', 'operação', 'brasileira;', 'controladora', 'também', 'cai']
#
#  aaaaa
#
# ['Oportunidade:', 'conheça', 'a', 'ação', 'que', 'pode', 'crescer', '50%', 'ou', 'mais', 'com', 'o', 'fim', 'do', 'monopólio', 'do', 'gás', 'pela', 'Petrobras', '(PETR4)']
#
#  aaaaa
#
# ['Ibovespa', '(IBOV)', 'sustenta', 'alta', 'e', 'marca', '4º', 'pregão', 'seguido', 'de', 'ganhos']
#
#  aaaaa
#
# ['Rússia', 'diz', 'que', 'Ucrânia', 'está', 'por', 'trás', 'do', 'assassinato', 'da', 'filha', 'de', 'ultranacionalista']
#
#  aaaaa
#
# ['5', 'ações', 'para', 'investir', 'em', 'setembro:', 'analista', 'que', 'acumulou', 'rendimento', 'de', '360%', 'do', 'Ibovespa', 'em', 'agosto', 'criou', 'nova', 'lista', 'com', 'papéis', 'exclusivos;', 'confira']
#
#  aaaaa
#
# ['Lula', 'tem', '43%', 'das', 'intenções', 'de', 'voto', 'e', 'distância', 'entre', 'Bolsonaro', 'cai', 'para', '7', 'pontos,', 'diz', 'FSB/BTG']
#
#  aaaaa
#
# ['Força', 'aérea', 'de', 'Taiwan', 'mostra', 'força', 'diante', 'de', 'exercícios', 'militares', 'da', 'China']
#
#  aaaaa
#
# ['Ibovespa', '(IBOV)', 'acelera', 'ritmo', 'de', 'queda,', 'sob', 'peso', 'das', 'commodities']
#
#  aaaaa
#
# ['IRB', '(IRBR3)', 'cai', '14%', 'em', 'agosto;', 'o', 'que', 'fez', 'ação', 'atingir', 'mínima', 'histórica?']
#
#  aaaaa
#
# ['Ecorodovias', '(ECOR3),', 'Vibra', '(VBBR3)', 'e', 'Dexco', '(DXCO3)', 'são', 'as', 'novidades', 'da', 'carteira', 'de', 'ações', 'da', 'Terra', 'Investimentos']
#
#  aaaaa
#
# ['Credit', 'Suisse', 'avalia', 'demitir', 'cerca', 'de', '5', 'mil', 'funcionários,', 'diz', 'Reuters']
#
#  aaaaa
#
# ['Bolsas', 'de', 'Nova', 'York', 'fecham', 'mistas,', 'com', 'investidores', 'à', 'espera', 'do', 'payroll']
#
#  aaaaa
#
# ['Independência', 'financeira:', 'Quanto', 'investir', 'para', 'parar', 'de', 'trabalhar', 'aos', '40', 'anos?']
#
#  aaaaa
#
# ['Ibovespa', '(IBOV)', 'opera', 'sem', 'forças', 'nesta', 'terça-feira', '(30)']
#
#  aaaaa
#
# ['Petróleo', 'opera', 'sem', 'direção', 'única,', 'pressionado', 'por', 'acordo', 'nuclear', 'mais', 'próximo', 'e', 'possível', 'corte', 'da', 'Opep+']
#
#  aaaaa
#
# ['Day', 'Trade:', '9', 'ações', 'para', 'comprar', 'hoje', 'e', 'buscar', 'até', '3,67%,', 'segundo', 'Ágora,', 'BTG', 'e', 'PagBank']
#
#  aaaaa
#
# ['PRIO3', 'dispara', 'quase', '8%', 'com', 'aquisição', 'da', 'antiga', 'OGX', 'de', 'Eike', 'Batista']
#
#  aaaaa
#
# ['Pré-Mercado:', 'Se', 'for', 'para', 'sofrer,', 'que', 'seja', 'com', 'classe']
#
#  aaaaa
#
# ['Day', 'Trade:', '8', 'ações', 'para', 'comprar', 'hoje', 'e', 'buscar', 'até', '3,36%,', 'segundo', 'Ágora,', 'BTG', 'e', 'PagBank']
#
#  aaaaa
#
# ['Agosto', 'do', 'gringo:', 'dólar', 'mostra', 'resiliência', 'com', 'enxurrada', 'de', 'dinheiro', 'entrando', 'no', 'país', 'enquanto', 'exterior', 'pega', 'fogo']
#
#  aaaaa
#
# ['Marfrig', '(MRFG3)', 'sofre', 'queda', 'exagerada', 'na', 'Bolsa', 'e', 'XP', 'diz', 'que', 'é', 'hora', 'de', 'comprar']
#
#  aaaaa
#
# ['Petrobras', '(PETR4),', 'Fleury', '(FLRY3)', 'e', 'top', '5', 'ações', 'para', 'investir', 'na', 'semana,', 'segundo', 'Warren']
#
#  aaaaa
#
# ['Ação', 'esquecida', 'de', 'commodity', 'tem', 'bons', 'dividendos', 'e', 'pode', 'ser', 'alternativa', 'à', 'Vale', '(VALE3)']
#
#  aaaaa
#
# ['Portos', 'seguros', 'da', 'inflação:', 'Veja', 'quais', 'ações', 'investir', 'com', 'a', 'perspectiva', 'de', 'alta', 'do', 'IPCA']
#
#  aaaaa
#
# ['Índices', 'de', 'NY', 'perdem', 'mais', 'de', '4%', 'em', 'agosto;', 'o', 'que', 'deu', 'errado?']
#
#  aaaaa
#
# ['Deutsche', 'vê', 'risco', 'de', 'S&P', '500', 'cair', 'mais', '25%', 'se', 'houver', 'recessão']
#
#  aaaaa
#
# ['Minério', 'de', 'ferro', 'tem', 'nova', 'queda', 'na', 'China', '(Dalian)', 'e', 'cai', '6,5%', 'na', 'semana']
#
#  aaaaa
#
# ['Homem', 'mais', 'rico', 'do', 'mundo', 'também', 'é', 'o', 'CEO', 'mais', 'bem', 'pago;', 'Veja', 'o', 'ranking', 'dos', 'maiores', 'salários']
#
#  aaaaa
#
# ['Aliansce', 'Sonae', '(ALSO3)', 'encerra', 'oferta', 'de', 'R$', '1', 'bilhão', 'em', 'debêntures;', 'veja', 'a', 'rentabilidade']
#
#  aaaaa
#
# ['PagBank', 'escala', 'ações', 'para', 'ganhar', 'com', 'possível', 'queda', 'da', 'inflação', 'em', 'setembro;', 'veja', 'os', 'nomes']
#
#  aaaaa
#
# ['Ibovespa', 'pode', 'aproveitar', 'alta', 'do', 'petróleo', 'e', 'Ásia', 'fecha', 'em', 'cima', 'do', 'muro']
#
#  aaaaa
#
# ['StoneCo', 'tem', 'prejuízo', 'no', '2°', 'tri', 'com', 'impacto', 'de', 'Inter', '(BIDI11);', 'Ação', 'desaba']
#
#  aaaaa
#
# ['Panvel', '(PNVL3)', 'anuncia', 'programa', 'de', 'recompra', 'de', 'até', '2', 'milhões', 'de', 'ações']
#
#  aaaaa
#
# ['Ibovespa', 'opera', 'estável', 'após', 'falas', 'do', 'presidente', 'do', 'Federal', 'Reserve']
#
#  aaaaa
#
# ['5', 'ações', 'para', 'investir', 'na', 'última', 'semana', 'de', 'agosto,', 'segundo', 'a', 'Terra']
#
#  aaaaa
#
# ['5', 'empresas', 'que', 'devem', 'se', 'destacar', 'na', 'semana', 'para', 'ter', 'na', 'carteira,', 'segundo', 'Warren']
#
#  aaaaa
#
# ['Ação', 'mais', 'indicada', 'da', 'semana', 'é', 'agro;', 'veja', 'o', 'melhor', 'de', '10', 'carteiras']
#
#  aaaaa
#
# ['Petrobras', '(PETR4)', 'salta', '3%', 'com', 'reinvestimento', 'de', 'dividendos;', 'ação', 'recupera', 'tombo', 'de', 'ontem']
#
#  aaaaa
#
# ['Cielo', '(CIEL3):', 'Ação', 'está', 'no', 'limite,', 'alerta', 'Bank', 'of', 'America']
#
#  aaaaa
#
# ['Investidores', 'estão', 'fugindo', 'das', 'mineradoras;', 'o', 'que', 'explica', 'a', 'falta', 'de', 'posição', 'em', 'materiais', 'básicos?']
#
#  aaaaa
#
# ['Ibovespa', '(IBOV)', 'perde', 'força', 'com', 'virada', 'para', 'o', 'negativo', 'em', 'NY']
#
#  aaaaa
#
# ['Day', 'Trade:', 'Vivo', '(VIVT3),', 'Weg', '(WEGE3)', 'e', 'mais', '7', 'ações', 'para', 'vender', 'hoje', 'e', 'buscar', 'até', '3,19%']
#
#  aaaaa
#
# ['Ibovespa', 'também', 'é', 'agro', 'com', 'inclusões', 'de', 'RAIZ4', 'e', 'SMTO3.', 'O', 'que', 'esperar', 'das', 'ações?']
#
#  aaaaa
#
# ['Dólar', 'e', 'Ibovespa', 'futuro', 'operam', 'em', 'queda', 'nesta', 'sexta-feira', '(2);', 'veja', 'o', 'que', 'move', 'o', 'dia']
#
#  aaaaa
#
# ['Burger', 'King', '(BKBR3)', 'recua', '2%', 'após', 'conselho', 'se', 'opor', 'à', 'oferta', 'do', 'Mubadala']
#
#  aaaaa
#
# ['CSN', '(CSNA3)', 'anuncia', 'emissão', 'de', 'R$', '675', 'milhões', 'em', 'debêntures']
#
#  aaaaa
#
# ['O', 'pior', 'ficou', 'para', 'trás,', 'diz', 'gestora,', 'e', 'é', 'hora', 'de', 'se', 'expor;', 'veja', 'ações', 'que', 'ganham', 'com', 'a', 'retomada']
#
#  aaaaa
#
# ['Fundos', 'imobiliários:', 'Arton', 'Advisors', 'aloca', 'R$', '50', 'milhões', 'em', 'um', 'dos', 'maiores', 'pagadores', 'de', 'dividendos', 'da', 'indústria']
#
#  aaaaa
#
# ['5', 'ações', 'para', 'comprar', 'e', 'lucrar', 'nesta', 'semana,', 'segundo', 'a', 'MyCap']
#
#  aaaaa
#
# ['Brasil', 'ganha', 'material', 'biológico', 'para', 'vacina', 'contra', 'varíola', 'dos', 'macacos']
#
#  aaaaa
#
# ['Ações', 'de', 'varejo', 'voltam', 'a', 'atrair', 'gestor', 'com', 'perspectiva', 'do', 'fim', 'de', 'altas', 'da', 'Selic;', 'veja', 'os', 'nomes']
#
#  aaaaa
#
# ['Eleições', 'põem', 'superministério', 'da', 'Economia', 'em', 'xeque']
#
#  aaaaa
#
# ['Ibovespa', '(IBOV):', 'Discurso', 'de', 'Powell', 'em', 'Jackson', 'Hole', 'pressiona,', 'e', 'índice', 'fecha', 'em', 'queda', 'de', '1%']
#
#  aaaaa
#
# ['Índices', 'de', 'ações', 'na', 'China', 'fecham', 'no', 'azul,', 'mas', 'dados', 'de', 'comércio', 'minam', 'ganhos']
#
#  aaaaa
#
# ['Com', 'queda', 'global', 'de', 'IPOs,', 'grandes', 'ofertas', 'de', 'ações', 'vêm', 'da', 'China']
#
#  aaaaa
#
# ['T4F', '(SHOW3):', 'Cancelamento', 'de', 'shows', 'de', 'Justin', 'Bieber', 'derruba', 'ação']
#
#  aaaaa
#
# ['Marco', 'regulatório', 'das', 'criptomoedas:', 'rumo', 'à', 'transparência', 'e', 'segurança', 'nas', 'operações', 'brasileiras']
#
#  aaaaa
#
# ['Ibovespa', 'tomba', '1,68%', 'e', 'retorna', 'aos', '110', 'mil', 'pontos', 'com', 'fraqueza', 'das', 'commodities']
#
#  aaaaa
#
# ['IMC', '(MEAL3)', 'salta', '3%', 'após', 'anunciar', 'venda', 'da', 'Carl’s', 'Jr.', 'no', 'Panamá']
#
#  aaaaa
#
# ['Espaçolaser', '(ESPA3)', 'despenca', '17%', 'após', 'ofertar', 'ações', 'com', 'desconto', 'de', '20%']
#
#  aaaaa
#
# ['Petrobras', '(PETR4)', 'opera', 'em', 'queda', 'com', 'novo', 'conselho', 'e', 'baixa', 'do', 'petróleo']
#
#  aaaaa
#
# ['Ibovespa', '(IBOV)', 'fecha', 'em', 'alta', 'agressiva', 'de', 'mais', 'de', '2%', 'com', 'apoio', 'de', 'commodities;', 'VALE3', 'salta', '6%']
#
#  aaaaa
#
# ['CPFL', '(CPFE3)', 'manifesta', 'interesse', 'em', 'exercer', 'preferência', 'na', 'aquisição', 'de', 'ações', 'da', 'Enercan']
#
#  aaaaa
#
# ['Efeito', 'das', 'eleições?', 'O', 'que', 'explica', 'a', 'maior', 'queda', 'de', 'Banco', 'do', 'Brasil', '(BBAS3)', 'em', '11', 'meses?']
#
#  aaaaa
#
# ['Ibovespa', 'hoje:', 'Mercado', 'testa', 'dinâmica', 'própria', 'após', 'encerrar', 'agosto', 'à', 'prova', 'de', 'choques', 'externos']
#
#  aaaaa
#
# ['Ibovespa', 'pode', 'retomar', 'rali', 'de', 'alta', 'com', 'apetite', 'no', 'exterior;', 'Hong', 'Kong', 'salta', '3,63%']
#
#  aaaaa
#
# ['Coluna', 'do', 'TradingView:', 'Juros', 'da', 'zona', 'do', 'Euro', 'e', 'fala', 'do', 'Powell', 'movem', 'o', 'mercado']
#
#  aaaaa
#
# ['XP', 'arremata', 'bloco', 'do', 'aeroporto', 'Campo', 'de', 'Marte', 'no', 'leilão', 'da', 'ANAC', 'por', 'R$', '141,4', 'milhões']
#
#  aaaaa
#
# ['O', 'inverno', 'sem', 'fim', 'para', 'IRB', '(IRBR3).', 'De', 'quem', 'é', 'a', 'culpa', 'e', 'quando', 'vai', 'mudar?']
#
#  aaaaa
#
# ['Wall', 'Street:', 'Índices', 'aceleram', 'ganhos', 'antes', 'de', 'Livro', 'Bege']
#
#  aaaaa
#
# ['Arábia', 'Saudita', 'diz', 'que', 'pode', 'fechar', 'torneira', 'para', '‘salvar’', 'derretimento', 'de', 'preços;', 'petróleo', 'sobe', '3,5%']
#
#  aaaaa
#
# ['Veja', 'as', 'ações', 'gringas', 'que', 'devem', 'entrar', 'no', 'seu', 'radar', 'em', 'setembro,', 'segundo', '17', 'analistas']
#
#  aaaaa
#
# ['Ibovespa', 'pode', 'ir', 'na', 'contramão', 'de', 'mercados', 'em', 'queda;', 'ações', 'na', 'China', 'derrapam']
#
#  aaaaa
#
# ['Ibovespa', 'hoje:', 'Volta', 'do', 'feriado', 'nos', 'EUA', 'precede', 'pausa', 'no', 'Brasil']
#
#  aaaaa
#
# ['5', 'ações', 'para', 'comprar', 'agora', 'e', 'lucrar', 'nesta', 'semana,', 'segundo', 'BTG']
#
#  aaaaa
#
# ['IRB', '(IRBR3)', 'vende', 'sede', 'no', 'Rio', 'de', 'Janeiro', 'por', 'R$', '85,3', 'milhões']
#
#  aaaaa
#
# ['‘Dividendos', 'extremos’', 'com', 'fazendas:', 'FII', 'do', 'agronegócio', 'é', 'um', 'dos', 'melhores', 'do', 'setor', 'e', 'gera', 'renda', 'extra', 'mensal', 'acima', 'da', 'Selic;', 'ele', 'virou', 'uma', '‘máquina', 'de', 'juros', 'compostos’', 'com', 'dividendos', 'de', 'quase', '14%', 'ao', 'ano']
#
#  aaaaa
#
# ['Small', 'caps:', 'Ação', 'de', 'petroleira', 'ganha', 'destaque', 'entre', 'analistas', 'e', 'é', 'eleita', 'a', 'melhor', 'para', 'setembro']
#
#  aaaaa
#
# ['Petição', 'de', 'liquidação', 'da', 'Evergrande', 'em', 'Hong', 'Kong', 'é', 'adiada', 'para', '7', 'de', 'novembro']
#
#  aaaaa
#
# ['Day', 'Trade:', 'Petrobras', '(PETR4),', 'Weg', '(WEGE3)', 'e', 'mais', '7', 'ações', 'para', 'comprar', 'hoje', 'e', 'buscar', 'até', '3,51%']
#
#  aaaaa
#
# ['Exxon', 'Mobil', '(EXXO34)', 'é', 'a', 'novidade', 'da', 'carteira', 'de', 'BDRs', 'da', 'Órama', 'para', 'setembro;', 'veja', 'lista', 'completa']
#
#  aaaaa
#
# ['Fundos', 'de', 'investimento', 'revertem', 'movimento', 'negativo', 'e', 'fecham', 'agosto', 'com', 'captação', 'líquida', 'positiva', 'de', 'R＄', '3,7', 'bilhões']
#
#  aaaaa
#
# ['Flávio', 'Augusto:', '‘Mundo', 'acadêmico', 'deixa', 'muito', 'a', 'desejar', 'na', 'área', 'de', 'tecnologia’']
#
#  aaaaa
#
# ['13º', 'salário', '‘turbinado’:', 'você', 'pode', 'receber', 'um', 'bônus', 'de', 'R$', '8', 'mil', 'a', 'R$', '10', 'mil', 'todo', 'final', 'de', 'ano', 'direto', 'na', 'sua', 'conta;', 'saiba', 'como']
#
#  aaaaa
#
# ['STF', 'encerra', 'ação', 'de', 'senadores', 'contra', 'procuradora', 'que', 'pediu', 'arquivamento', 'de', 'investigações', 'contra', 'Bolsonaro']
#
#  aaaaa
#
# ['Bancos', 'lideram', 'avanço', 'de', 'índices', 'europeus', 'após', 'alta', 'de', 'juros', 'recorde', 'do', 'BCE']
#
#  aaaaa
#
# ['Ações', 'europeia', 'encerram', 'sequência', 'de', 'três', 'dias', 'de', 'perdas', 'com', 'alta', 'de', 'setores', 'defensivos']
#
#  aaaaa
#
# ['Efeito', 'Rial:', 'Cielo', '(CIEL3)', 'pode', 'disparar', 'com', 'chegada', 'de', 'novo', 'CEO?']
#
#  aaaaa
#
# ['Ibovespa', 'salta', 'mais', 'de', '1,5%', 'e', 'volta', 'aos', '112', 'mil', 'pontos', 'com', 'alívio', 'em', 'Wall', 'Street']
#
#  aaaaa
#
# ['“Substitutos”', 'de', 'PETR4', 'e', 'BBAS3:', 'Os', 'papéis', 'para', 'quem', 'quer', 'fugir', 'das', 'estatais', 'nas', 'eleições']
#
#  aaaaa
#
# ['Cielo', '(CIEL3)', 'continua', 'barata,', 'mesmo', 'após', 'salto', 'de', '160%,', 'avalia', 'BTG;', 'ação', 'tem', 'fôlego', 'para', 'subir', 'mais', '20%']
#
#  aaaaa
#
# ['Esses', 'investidores', 'brasileiros', 'lucraram', 'mais', 'de', '1.200%', 'com', 'maior', 'ação', 'de', 'infraestrutura', 'do', 'Brasil', ';', 'entenda', 'um', 'dos', 'melhores', 'investimentos', 'do', 'ramo']
#
#  aaaaa
#
# ['Ibovespa', '(IBOV)', 'não', 'escapa', 'do', 'mau', 'humor', 'generalizado', 'dos', 'mercados', 'e', 'fecha', 'em', 'forte', 'queda', 'de', '2%']
#
#  aaaaa
#
# ['Previsão', 'para', 'a', 'fala', 'de', 'Powell', 'em', 'simpósio', 'é', 'de', 'inflação', 'elevada', 'e', 'visibilidade', 'limitada']
#
#  aaaaa
#
# ['Pré-Mercado:', 'As', 'discussões', 'políticas', 'começam', 'a', 'aquecer']
#
#  aaaaa
#
# ['Opções', 'de', 'venda', 'não', 'funcionaram', 'e', 'o', 'Goldman', 'tem', 'uma', 'ideia', 'melhor']
#
#  aaaaa
#
# ['CSU', 'CardSystem', 'vira', 'CSU', 'Digital', 'e', 'passa', 'a', 'ser', 'negociada', 'como', 'CSUD3', 'na', 'B3']
#
#  aaaaa
#
# ['Ibovespa', 'ensaia', 'nova', 'alta', 'e', 'Austrália', 'eleva', 'juros,', 'mexendo', 'com', 'ações', 'na', 'Ásia']
#
#  aaaaa
#
# ['XP', 'seleciona', 'Vale', '(VALE3)', 'e', 'outras', '4', 'ações', 'para', 'investir', 'e', 'lucrar', 'nesta', 'semana']
#
#  aaaaa
#
# ['Ibovespa', 'futuro', 'e', 'dólar', 'operam', 'em', 'queda', 'com', 'exterior', 'negativo']
#
#  aaaaa
#
# ['Dólar', 'e', 'Ibovespa', 'futuro', 'operam', 'em', 'alta', 'nesta', 'segunda', '(5);', 'veja', 'o', 'que', 'move', 'o', 'dia']
#
#  aaaaa
#
# ['Títulos', 'globais', 'caem', 'em', 'primeiro', 'mercado', 'de', 'baixa', 'em', 'uma', 'geração']
#
#  aaaaa
#
# ['Mineradoras', 'e', 'siderúrgicas', 'engatam', 'alta', 'firme', 'na', 'Bolsa;', 'USIM5', 'dispara', 'quase', '8%', 'e', 'VALE3', 'avança', '4%']
#
#  aaaaa
#
# ['Marcopolo', '(POMO4):', '6', 'motivos', 'para', 'acreditar', 'no', 'potencial', 'das', 'ações,', 'segundo', 'Itaú', 'BBA']
#
#  aaaaa
#
# ['Ucrânia', 'enfrentará', 'inverno', 'mais', 'difícil', 'até', 'agora,', 'mas', 'meta', 'de', 'reserva', 'de', 'gás', 'deve', 'ser', 'alcançada']
#
#  aaaaa
#
# ['Ibovespa', '(IBOV)', 'acompanha', 'virada', 'em', 'Wall', 'Street', 'e', 'cai,', 'mas', 'encerra', 'mês', 'com', 'valorização']
#
#  aaaaa
#
# ['Ibovespa', '(IBOV)', 'fecha', 'em', 'alta', 'e', 'recupera', 'os', '113', 'mil', 'pontos', 'antes', 'de', 'discurso', 'de', 'Powell', 'em', 'Jackson', 'Hole']
#
#  aaaaa
#
# ['Ambev', '(ABEV3)', 'está', 'com', 'desconto', 'de', '30%,', 'calcula', 'Credit', 'Suisse']
#
#  aaaaa
#
# ['brMalls', '(BRML3),', 'Gerdau', '(GGBR4)', 'e', 'mais:', 'Veja', 'as', 'ações', 'escaladas', 'pela', 'XP', 'para', 'superar', 'o', 'Ibovespa', 'nesta', 'semana']
#
#  aaaaa
#
# ['TSE', 'homologa', 'candidatura', 'de', 'Bolsonaro;', 'Tribunal', 'cancela', 'candidatura', 'de', 'Marçal', 'e', 'aprova', 'apoio', 'de', 'Pros', 'à', 'Lula']
#
#  aaaaa
#
# ['Ibovespa', '(IBOV)', 'reduz', 'ganhos', 'com', 'Wall', 'Street,', 'mas', 'se', 'mantém', 'acima', 'dos', '110', 'mil', 'pontos']
#
#  aaaaa

# %% [raw]
# verd0 = verificador.loc[(verificador.comp == 0) & (verificador.Target == 0)]
# verd1 = verificador.loc[(verificador.comp == 1) & (verificador.Target == 1)]
# verd2 = verificador.loc[(verificador.comp == 2) & (verificador.Target == 2)]
#
# fals0 = verificador.loc[(verificador.comp == 0) & (verificador.Target != 0)]
# fals1 = verificador.loc[(verificador.comp == 1) & (verificador.Target != 1)]
# fals2 = verificador.loc[(verificador.comp == 2) & (verificador.Target != 2)]
#
# print(f'O percentual de verdadeiros negativos foi de: {100 * (verd0.shape[0] / verificador.shape[0]):.2f}%')
# print(f'O percentual de falsos negativos foi de: {100 * (fals0.shape[0] / verificador.shape[0]):.2f}%')
# print(f'O percentual de verdadeiros neutros foi de: {100 * (verd1.shape[0] / verificador.shape[0]):.2f}%')
# print(f'O percentual de falsos neutros foi de: {100 * (fals1.shape[0] / verificador.shape[0]):.2f}%')
# print(f'O percentual de verdadeiros positivos foi de: {100 * (verd2.shape[0] / verificador.shape[0]):.2f}%')
# print(f'O percentual de falsos positivos foi de: {100 * (fals2.shape[0] / verificador.shape[0]):.2f}%')

# %%
print(f'A acurácia do modelo foi de: {100 * (verd0 + verd1 + verd2).shape[0] / test.shape[0]:.2f}%')
# Out:
# A acurácia do modelo foi de: 36.33%
